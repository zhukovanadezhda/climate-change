# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

from scripts import toolbox as tb

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = "data/co2_surface-insitu_ccgg_text/co2_brw_surface-insitu_1_ccgg_MonthlyData.txt"
df = pd.read_csv(data, comment="#", sep=" ", header=0)
df.drop(columns="qcflag", inplace=True)

# %%
df.describe()
# Out:
#               year       month    day   hour  minute  second  time_decimal  \
# count   593.000000  593.000000  593.0  593.0   593.0   593.0    593.000000
# mean   1997.789207    6.529511    1.0    0.0     0.0     0.0   1998.248087
# std      14.278755    3.457692    0.0    0.0     0.0     0.0     14.277380
# min    1973.000000    1.000000    1.0    0.0     0.0     0.0   1973.580822
# 25%    1985.000000    4.000000    1.0    0.0     0.0     0.0   1985.915068
# 50%    1998.000000    7.000000    1.0    0.0     0.0     0.0   1998.246575
# 75%    2010.000000   10.000000    1.0    0.0     0.0     0.0   2010.580822
# max    2022.000000   12.000000    1.0    0.0     0.0     0.0   2022.915068
#
#        midpoint_time       value  value_std_dev      nvalue      latitude  \
# count   5.930000e+02  593.000000     593.000000  593.000000  5.930000e+02
# mean    8.927452e+08  368.171197       1.215396   27.252951  7.132300e+01
# std     4.505603e+08   62.188496       4.242857    4.204256  1.422285e-14
# min     1.143252e+08 -999.990000     -99.990000    0.000000  7.132300e+01
# 25%     5.035572e+08  348.090000       0.720000   26.000000  7.132300e+01
# 50%     8.927028e+08  367.210000       1.240000   28.000000  7.132300e+01
# 75%     1.281935e+09  391.840000       1.840000   30.000000  7.132300e+01
# max     1.671167e+09  426.110000       4.400000   31.000000  7.132300e+01
#
#           longitude    altitude  elevation  intake_height
# count  5.930000e+02  593.000000      593.0     593.000000
# mean  -1.566110e+02   27.543744       11.0      16.543744
# std    2.844570e-14    3.564918        0.0       3.564918
# min   -1.566110e+02    1.100000       11.0      -9.900000
# 25%   -1.566110e+02   27.460000       11.0      16.460000
# 50%   -1.566110e+02   27.460000       11.0      16.460000
# 75%   -1.566110e+02   27.460000       11.0      16.460000
# max   -1.566110e+02   46.050000       11.0      35.050000

# %%
tb.plot_boxplots(df, "Barrow Observatory, Alaska, USA")

# %%
df = tb.convert_to_datetime(df)
df = tb.drop_missing_values(df)
df = tb.correct_season(df)
tb.plot_timeseries(df, "Barrow Observatory, Alaska, USA")

# %%
data = "data/co2_surface-insitu_ccgg_text/co2_mlo_surface-insitu_1_ccgg_MonthlyData.txt"
df = pd.read_csv(data, comment="#", sep=" ", header=0)
df.drop(columns="qcflag", inplace=True)

# %%
tb.plot_boxplots(df, "Mauna Loa, Hawaii, USA")

# %%
df = tb.convert_to_datetime(df)
df = tb.drop_missing_values(df)
df = tb.correct_season(df)
tb.plot_timeseries(df, "Mauna Loa, Hawaii, USA")

# %%
data = "data/co2_surface-insitu_ccgg_text/co2_smo_surface-insitu_1_ccgg_MonthlyData.txt"
df = pd.read_csv(data, comment="#", sep=" ", header=0)
df.drop(columns="qcflag", inplace=True)

# %%
tb.plot_boxplots(df, "American Samoa, USA")

# %%
df = tb.convert_to_datetime(df)
df = tb.drop_missing_values(df)
df = tb.correct_season(df)
tb.plot_timeseries(df, "American Samoa, USA")

# %%
from plotly.subplots import make_subplots

fig = make_subplots(rows=1, cols=2)

fig = px.line(df, x='datetime', y='value', labels={'datetime': 'Time', 'value': 'CO2 Concentration'},
              title='CO2 Concentration Over Time')

fig.update_traces(mode='lines+markers', hovertemplate='%{y:.2f} ppm<br>%{x}', line=dict(width=2))

fig.show()
# Out:
# /home/nadia/miniconda3/envs/everything/lib/python3.11/site-packages/_plotly_utils/basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# <div>                            <div id="61a81b96-dd77-4360-826c-81a034b59d1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61a81b96-dd77-4360-826c-81a034b59d1d")) {                    Plotly.newPlot(                        "61a81b96-dd77-4360-826c-81a034b59d1d",                        [{"hovertemplate":"%{y:.2f} ppm\u003cbr\u003e%{x}","legendgroup":"","line":{"color":"#636efa","dash":"solid","width":2},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["